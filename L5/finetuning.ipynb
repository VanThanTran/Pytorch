# %%
import torch, torchvision
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from torchvision.datasets import CIFAR100

import time
from torchsummary import summary

import numpy as np
import matplotlib.pyplot as plt
import os

from PIL import Image

# %%
# Applying Transforms to the Data
train_transform = transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

test_transform = transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %%
train_data = CIFAR100(download=True, root="./data", transform=train_transform)
test_data = CIFAR100(root="./data", train=False,transform=test_transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
#   0%|          | 0/169001437 [00:00<?, ?it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data

# %%
# batch size
bs = 32
train_data_loader = DataLoader(train_data, batch_size=bs, shuffle=True)
test_data_loader = DataLoader(test_data, batch_size=bs, shuffle=True)

# %%
train_data_size = len(train_data)
test_data_size = len(test_data)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Load pretrained ResNet50 Model
resnet50 = models.resnet50(pretrained=True)
resnet50 = resnet50.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
print(type(test_data))
# Out:
# <class 'torchvision.datasets.cifar.CIFAR100'>

# %%
# Freeze model parameters
# for param in resnet50.parameters():
#     param.requires_grad = False

# %%
# Freeze layers 1-6 in total 10 layers of Resnet50
ct = 0
for child in resnet50.children():
  ct += 1
  if ct < 7:
      for param in child.parameters():
          param.requires_grad = False

# %%
# Change the final layer of ResNet50 Model for Transfer Learning
fc_inputs = resnet50.fc.in_features

resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 100), # Since 100 possible outputs
    nn.LogSoftmax(dim=1) # For using NLLLoss()
)

# Convert model to be used on GPU
resnet50 = resnet50.to(device)

# %%
# Define Optimizer and Loss Function
loss_func = nn.NLLLoss()

# %%
def train_and_validate(model, loss_criterion, optimizer, scheduler,epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_loss = 100000.0
    best_epoch = None

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(train_data_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            scheduler.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(test_data_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)
                if not j%100:
                  print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
        if valid_loss < best_loss:
            best_loss = valid_loss
            best_epoch = epoch

        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_valid_loss = valid_loss/test_data_size 
        avg_valid_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss - {:.4f}, Accuracy - {:.4f}%, \n\t\tValidation : Loss - {:.4f}, Accuracy - {:.4f}%, Time: {:.4f}s".format(epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'model_'+str(epoch)+'.pt')
            
    return model, history, best_epoch

# %%
num_epochs = 25
optimizer = optim.Adam(resnet50.parameters(), lr=0.005)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[10,20], gamma=0.1)
trained_model, history, best_epoch = train_and_validate(resnet50, loss_func, optimizer, scheduler, num_epochs)
torch.save(history, 'history.pt')
# Out:
# Epoch: 1/25
# Validation Batch number: 000, Validation: Loss: 4.5966, Accuracy: 0.0000
# Validation Batch number: 100, Validation: Loss: 4.5757, Accuracy: 0.0000
# Validation Batch number: 200, Validation: Loss: 4.5843, Accuracy: 0.0000
# Validation Batch number: 300, Validation: Loss: 4.6002, Accuracy: 0.0000
# Epoch : 001, Training: Loss - 4.6211, Accuracy - 1.0440%,
# 		Validation : Loss - 4.5964, Accuracy - 1.9500%, Time: 456.0443s
# Epoch: 2/25
# Validation Batch number: 000, Validation: Loss: 4.1594, Accuracy: 0.0312
# Validation Batch number: 100, Validation: Loss: 4.1733, Accuracy: 0.0312
# Validation Batch number: 200, Validation: Loss: 4.1998, Accuracy: 0.0000
# Validation Batch number: 300, Validation: Loss: 4.1316, Accuracy: 0.0625
# Epoch : 002, Training: Loss - 4.4318, Accuracy - 2.6500%,
# 		Validation : Loss - 4.0818, Accuracy - 6.1200%, Time: 460.2177s
# Epoch: 3/25
# Validation Batch number: 000, Validation: Loss: 3.3227, Accuracy: 0.2188
# Validation Batch number: 100, Validation: Loss: 3.3083, Accuracy: 0.1875
# Validation Batch number: 200, Validation: Loss: 3.6339, Accuracy: 0.1250
# Validation Batch number: 300, Validation: Loss: 3.3684, Accuracy: 0.1875
# Epoch : 003, Training: Loss - 3.9556, Accuracy - 7.1920%,
# 		Validation : Loss - 3.4658, Accuracy - 14.3900%, Time: 463.9864s
# Epoch: 4/25
# Validation Batch number: 000, Validation: Loss: 2.8704, Accuracy: 0.3438
# Validation Batch number: 100, Validation: Loss: 2.9800, Accuracy: 0.1875
# Validation Batch number: 200, Validation: Loss: 3.3878, Accuracy: 0.1875
# Validation Batch number: 300, Validation: Loss: 3.2495, Accuracy: 0.1250
# Epoch : 004, Training: Loss - 3.5218, Accuracy - 12.6300%,
# 		Validation : Loss - 3.0088, Accuracy - 22.6800%, Time: 464.3462s
# Epoch: 5/25
# Validation Batch number: 000, Validation: Loss: 2.8092, Accuracy: 0.1250
# Validation Batch number: 100, Validation: Loss: 2.5881, Accuracy: 0.1875
# Validation Batch number: 200, Validation: Loss: 2.5711, Accuracy: 0.3125
# Validation Batch number: 300, Validation: Loss: 2.7026, Accuracy: 0.2500
# Epoch : 005, Training: Loss - 3.2030, Accuracy - 17.8180%,
# 		Validation : Loss - 2.6791, Accuracy - 29.2300%, Time: 465.0322s
# Epoch: 6/25
# Validation Batch number: 000, Validation: Loss: 2.4728, Accuracy: 0.3438
# Validation Batch number: 100, Validation: Loss: 2.5499, Accuracy: 0.3438
# Validation Batch number: 200, Validation: Loss: 2.0910, Accuracy: 0.4375
# Validation Batch number: 300, Validation: Loss: 2.8066, Accuracy: 0.2500
# Epoch : 006, Training: Loss - 2.9303, Accuracy - 23.2580%,
# 		Validation : Loss - 2.4030, Accuracy - 35.8000%, Time: 465.3245s
# Epoch: 7/25
# Validation Batch number: 000, Validation: Loss: 1.9944, Accuracy: 0.3750
# Validation Batch number: 100, Validation: Loss: 2.0342, Accuracy: 0.4688
# Validation Batch number: 200, Validation: Loss: 1.8377, Accuracy: 0.5000
# Validation Batch number: 300, Validation: Loss: 2.2526, Accuracy: 0.3750
# Epoch : 007, Training: Loss - 2.7154, Accuracy - 27.9660%,
# 		Validation : Loss - 2.2369, Accuracy - 38.8500%, Time: 466.0098s
# Epoch: 8/25
# Validation Batch number: 000, Validation: Loss: 2.1948, Accuracy: 0.4062
# Validation Batch number: 100, Validation: Loss: 1.8177, Accuracy: 0.3750
# Validation Batch number: 200, Validation: Loss: 2.1439, Accuracy: 0.5000
# Validation Batch number: 300, Validation: Loss: 2.1280, Accuracy: 0.4688
# Epoch : 008, Training: Loss - 2.5362, Accuracy - 32.3240%,
# 		Validation : Loss - 2.0721, Accuracy - 42.8800%, Time: 468.2664s
# Epoch: 9/25
# Validation Batch number: 000, Validation: Loss: 1.6591, Accuracy: 0.5000
# Validation Batch number: 100, Validation: Loss: 2.0779, Accuracy: 0.4688
# Validation Batch number: 200, Validation: Loss: 2.3454, Accuracy: 0.3750
# Validation Batch number: 300, Validation: Loss: 2.1077, Accuracy: 0.4375
# Epoch : 009, Training: Loss - 2.3849, Accuracy - 35.7320%,
# 		Validation : Loss - 1.9658, Accuracy - 46.4500%, Time: 468.7871s
# Epoch: 10/25
# Validation Batch number: 000, Validation: Loss: 2.0525, Accuracy: 0.4688
# Validation Batch number: 100, Validation: Loss: 2.0324, Accuracy: 0.4062
# Validation Batch number: 200, Validation: Loss: 2.0389, Accuracy: 0.4688
# Validation Batch number: 300, Validation: Loss: 2.3765, Accuracy: 0.3750
# Epoch : 010, Training: Loss - 2.2568, Accuracy - 39.0700%,
# 		Validation : Loss - 1.8706, Accuracy - 48.4000%, Time: 468.9814s
# Epoch: 11/25
# Validation Batch number: 000, Validation: Loss: 1.5524, Accuracy: 0.5625
# Validation Batch number: 100, Validation: Loss: 1.6190, Accuracy: 0.5938
# Validation Batch number: 200, Validation: Loss: 1.8102, Accuracy: 0.3750
# Validation Batch number: 300, Validation: Loss: 1.8113, Accuracy: 0.5000
# Epoch : 011, Training: Loss - 2.1398, Accuracy - 41.8300%,
# 		Validation : Loss - 1.7353, Accuracy - 51.8100%, Time: 469.8146s
# Epoch: 12/25
# Validation Batch number: 000, Validation: Loss: 1.9469, Accuracy: 0.4688
# Validation Batch number: 100, Validation: Loss: 1.6283, Accuracy: 0.5938
# Validation Batch number: 200, Validation: Loss: 1.7538, Accuracy: 0.4688
# Validation Batch number: 300, Validation: Loss: 1.6393, Accuracy: 0.5938
# Epoch : 012, Training: Loss - 2.0214, Accuracy - 44.8760%,
# 		Validation : Loss - 1.6666, Accuracy - 53.9500%, Time: 468.3735s
# Epoch: 13/25
# Validation Batch number: 000, Validation: Loss: 1.6284, Accuracy: 0.6250
# Validation Batch number: 100, Validation: Loss: 1.6193, Accuracy: 0.5625
# Validation Batch number: 200, Validation: Loss: 1.6110, Accuracy: 0.5625
# Validation Batch number: 300, Validation: Loss: 1.3687, Accuracy: 0.4688
# Epoch : 013, Training: Loss - 1.9313, Accuracy - 47.2620%,
# 		Validation : Loss - 1.5856, Accuracy - 55.4700%, Time: 469.6337s
# Epoch: 14/25
# Validation Batch number: 000, Validation: Loss: 1.4758, Accuracy: 0.5312
# Validation Batch number: 100, Validation: Loss: 1.9949, Accuracy: 0.4688
# Validation Batch number: 200, Validation: Loss: 1.7612, Accuracy: 0.5625
# Validation Batch number: 300, Validation: Loss: 1.6649, Accuracy: 0.5312
# Epoch : 014, Training: Loss - 1.8395, Accuracy - 49.6360%,
# 		Validation : Loss - 1.5414, Accuracy - 56.8200%, Time: 469.9524s
# Epoch: 15/25
# Validation Batch number: 000, Validation: Loss: 1.4724, Accuracy: 0.4688
# Validation Batch number: 100, Validation: Loss: 1.5219, Accuracy: 0.6875
# Validation Batch number: 200, Validation: Loss: 1.5158, Accuracy: 0.5625
# Validation Batch number: 300, Validation: Loss: 1.3696, Accuracy: 0.7812
# Epoch : 015, Training: Loss - 1.7618, Accuracy - 51.7460%,
# 		Validation : Loss - 1.4770, Accuracy - 58.2800%, Time: 468.4685s
# Epoch: 16/25
# Validation Batch number: 000, Validation: Loss: 1.2197, Accuracy: 0.6562
# Validation Batch number: 100, Validation: Loss: 1.3380, Accuracy: 0.6562
# Validation Batch number: 200, Validation: Loss: 1.1688, Accuracy: 0.6562
# Validation Batch number: 300, Validation: Loss: 1.2763, Accuracy: 0.5625
# Epoch : 016, Training: Loss - 1.6864, Accuracy - 53.5500%,
# 		Validation : Loss - 1.4550, Accuracy - 59.2700%, Time: 468.3728s
# Epoch: 17/25
